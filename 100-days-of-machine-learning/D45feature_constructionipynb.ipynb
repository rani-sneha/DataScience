# %% [markdown]
# <a href="https://colab.research.google.com/github/rani-sneha/DataScience/blob/main/100-days-of-machine-learning/D45feature_constructionipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Feature Construction | Feature Splitting

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Tidy data -
#
# Not tidy data - When 2 or more data is in one column.
#
# Eg- Mr Ranjit Anand
#
# Here we have 2 data Mr as in gender and name as in name
# Here we apply feature splitting splitting it into 2 columns.
#
# Feature construction - Using more than equal to 2 columns thus improving model outcome

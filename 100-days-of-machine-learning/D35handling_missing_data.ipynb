# %% [markdown]
# <a href="https://colab.research.google.com/github/rani-sneha/DataScience/blob/main/100-days-of-machine-learning/D35handling_missing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Handling Missing Data

# %% [markdown]
# 37-40 Missing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ways to fill Missing Values :-
#
# **1. Remove Them**
#
# **2. Impute/Fill Values**
# ```
#   a. Univariate
# ```
#             i. Numerical
#
# ```
#             ia. Mean/Median
#             ib. Random
#             ic. End of distribution Value
#
# ```
#             ii Categorical
# ```
#             ia. Mode
#             ib. Simply write 'Missing'
# ```
#       b. Multivariate
#
# ```
#         i. KNN imputer
#         ii. Iterative imputer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Complete Case Analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assumption of CCA
#
# 1) Missing Completely at Random (MCAR)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #When to use CCNA?

# %% [markdown]
# 1) MCAR
#
# 2)When missing data is less than 5% data

# %% [markdown]
# #Impute Missing Data (Numerical Data)

# %% [markdown]
# Univariant:- If for the missing value in a[2][2] you are filling it with the help of 2nd row only it is univariant.
#
# Multivariant:- If for the missing value in a[2][2] you are filling it with the help of other columns then it is multivariant

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When to use mean median ❎
# 1)<5%
# 2)MACR

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When to use arnitrary value :-
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
